# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010154/Computertational-Thinking-and-Program-Design/blob/main/%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 前情提要：女主26 朝九晚五的上班族 社交範圍小 被催婚 場景一：女主素顏去買早餐 看到一個超帥的帥哥在吃早餐）
#
# 場景一:
# Q1:要不要跟他要聯絡方式
# 要➡️拿到他的聯絡方式 給媽媽一個交代(好感度+5)
# 不要➡️男主撞倒你的早餐,因此加你的微信付錢,因此取得你的聯繫方式(好感度+0) 男生就問女生
# Q2:你家住哪裡
# 沉默➡️好感度不變 男生乾笑 兩個人說掰掰(好感度+0)
# 直接說➡️(好感度+5)
#
# 場景二： 兩個人就一起走 走到家才發現兩個人住對面
# Q1.要不要約男生明天一起吃早餐呢？
# 當然要！➡️男主有點意外，但也暗自竊喜，這個女生好可愛 (好感度+5)
# 先不要好了 好害羞➡️男主禮貌的說再見(好感度+0)
# Q2.要精心打扮，還是素顏赴約呢？
# 絕對要畫好畫滿！➡️男主非常驚訝女主的改變，完全就是自己的理想型 (好感度+10)
# 素顏！我希望他看到最真實的我➡️男主認為女主越看越可愛，和別的女生不一樣 (好感度+5)
# Q3吃早餐時會選擇甚麼話題當開頭呢？
# 1.喜歡和討厭的食物➡️討厭香菇、紅蘿蔔，但喜歡你 (好感度+20)
# 2.ㄟ~你喜歡什麼類型的女生阿？➡️ ㄣ…(害羞)像你這樣的 (好感度+5)
# 3.你今年幾歲、薪資多少巴拉巴拉的身家調查➡️你在身家調查嗎？(OS 關你啥事)(好感度-20)
# Q4.你們在吃早餐時相談甚歡，到了要各自去上班的時候，你會說什麼呢？
# 1.	謝謝你今天陪我吃早餐，你什麼時後有空呢
# ➡️我周末都有空呀，到時候再一起吃早餐吧！(好感度+5)
# 先走了喔，拜➡️男主錯愕.....以為女主不喜歡自己(好感度+0)
#
# 場景三:
# 已經持續一個月跟男主在周末吃早餐了，有時吃飽後也會一起去看電影、遊樂園等等，越來越喜歡男主角。而今天是週末又到了相約吃早餐的日子，決定今天要來試探男主角對你的心意。
# Q1你故意偷喝男主角的飲料，然後男主角剛好看見，這時你會... :
# 1.表情尷尬➡️男主一臉錯愕，但還是說:哈哈,沒事啦(好感度+5)
# 2.裝沒事➡️男主一臉錯愕，但還是說:哈哈,沒事啦(好感度+5)
#
# Q2吃完早餐一起回家時，男主角突然問你:剛剛是不小心喝錯我的飲料嗎？還是....。
# 1.	其實我有點喜歡你 (很害羞的臉) ➡️ 男主說:等一下!這種事應該我來說，我喜歡你2.沒有啦 真的不小心的，不要多想(極力否認) ➡️喔 真的嗎(一臉失望)(好感度-15)
#
# 場景四: 轉眼間，在一起一年半了，過去的日子媽媽一直催婚，而自己也想和他共組一個美滿的家庭，但不確定未來會怎樣，甚至有點害怕看不見的未知變數。
# 輸入好感度
# =80
# 1.相信他，相信我們能夠一起攜手走向幸福
# ➡️男主認為和女主之間沒有猜忌、懷疑，彼此都非常信任彼此，也相愛著。於是鼓起勇氣求婚。
# <80
# 2.擔心、害怕，雖然和男主已經在一起很久了，但還是時不時懷疑他外面有女人，或是不再愛自己了
# ➡️因為猜忌、懷疑，導致你們不斷爭吵，最後決定不再拖累彼此。

# %%
print("歡迎來到這個遊戲")
name = input("請輸入你的姓名: ")
print(f"我是{name},今年26歲，是個朝九晚五的上班族，總是被媽媽催婚")
## 場景一：女主素顏去買早餐 看到一個超帥的帥哥在吃早餐
print("你素顏去買早餐 看到一個超帥的帥哥在吃早餐")
print("Q1 這時，你要不要去跟他要聯絡方式")
answer = input("請輸入你的回答 ({1}要/{2}不要) : ")

if answer == "1":
    print("拿到他的聯絡方式，順便給媽媽一個交代 (好感度+5)")
else :
    print("男主意外撞倒你的早餐,身上又沒有多餘的零錢，因此給了你電話，決定下次還給你 (好感度+0)")
print("Q2.男生:你家住哪裡?")
answerb = input("請輸入你的回答 ({1}沉默/{2}直接說) : ")
if answerb == "1":
    print("男生乾笑,兩個人說掰掰,要回家時竟然不約而同朝同一個方向走(好感度+0)")
else :
    print("男主:我也是ㄟ!真巧(好感度+5)")
    
##場景二##
print("你們就一起走 走到家才發現兩個人竟然住在對面!")
print("你們兩個相視而笑。")
print("聊天過程很愉快，這時你決定明天要不要約男主吃早餐?")
alternative_choice1= input("[1]要 [2]不要")
if alternative_choice1=="1" :
  print("當然要！(男主有點意外，但也暗自竊喜，這個女生好可愛) (好感度+5)")
elif alternative_choice1=="2" :
  print("先不要好了，好害羞(好感度+0)")
  print("男生問你要不要明天一起吃早餐，你愉快地答應了")
print("明天和他一起吃飯的你要？")
alternative_choice2= input("[1]精心打扮 [2]素顏赴約")
if alternative_choice2=="1" :
  print("絕對要畫好畫滿！男主非常驚訝女主的改變，完全就是自己的理想型 (好感度+10)")
elif alternative_choice2=="2" :
  print("素顏！我希望他看到最真實的我!男主認為女主越看越可愛，和別的女生不一樣 (好感度+5)")
print("你一整個晚上都很期待明天的早餐之約。")
print("隔天，你和男主相約在家門口一起去吃早餐。")
print("一路上你們兩個都很害羞，不知道要怎麼開口打破沉默。")
print("你決定等一下在吃早餐的時候一定要主動開話題。")
print("吃早餐時會選擇甚麼話題當開頭呢？")
alternative_choice3 = input("[1]喜歡和討厭的食物 [2]ㄟ~你喜歡什麼類型的女生阿？[3] 你今年幾歲、薪資多少巴拉巴拉的身家調查 : ")
print("你的選擇是...", alternative_choice3)
if alternative_choice3 == "1":
  print("男生:我喜歡苦瓜、西瓜、哈密瓜")
  print("你:我不喜歡苦瓜、西瓜、哈密瓜，但喜歡你 (好感度+20)")
elif alternative_choice3 == "2":
  print("男主說:ㄣ…(害羞)像你這樣的。(好感度+5)")
else:
  print("男主確說:你在身家調查嗎？(OS 關你啥事)(好感度-20)")
print("你們在吃早餐時相談甚歡，到了要各自去上班的時候，你會說什麼呢？")
alternative_choice4 = input("[1]謝謝你今天陪我吃早餐，你什麼時後有空呢? [2]先走了喔，拜 : ")
print("你的選擇是...", alternative_choice4)
if alternative_choice4 == "1":
  print("我周末都有空呀，到時候再一起吃早餐吧！(好感度+5)")
else:
  print("男主錯愕.....以為你不喜歡自己(好感度+0)")
## 場景三已經持續一個月跟男主在周末吃早餐了，有時吃飽後也會一起去看電影、遊樂園等等，越來越喜歡男主角。而今天是週末又到了相約吃早餐的日子，ㄧㄝ。

print("已經持續一個月跟男主在周末吃早餐了，有時吃飽後也會一起去看電影、遊樂園等等，越來越喜歡男主角。而今天是週末又到了相約吃早餐的日子。")
print("見到男主角後你會？")
answerc = input("請輸入你的回答 ({1}我有點....(很害羞的臉)/{2}安於現狀，等待男主主動出擊) : 你的選擇是...")
if answerc == "1" :
    print("男主說:等一下!這種事應該我來說，我喜歡你。(好感度+30)")
else :
    print("男主說:我喜歡你(好感度+10)")
a = input("請累積你所得到的好感度並輸入 : ")

if a == "80":
  print("轉眼間，在一起兩年了，過去的日子媽媽一直催婚，而自己也想和他共組一個美滿的家庭，但不確定未來會怎樣，甚至有點害怕看不見的未知變數。")
  print("這時你選擇相信他，相信我們能夠一起攜手走向幸福")
  print("男主認為和女主之間沒有猜忌、懷疑，彼此都非常信任彼此，也相愛著。於是鼓起勇氣求婚。")
else :
  print("轉眼間，在一起兩年了，過去的日子媽媽一直催婚，而自己也想和他共組一個美滿的家庭，但不確定未來會怎樣，甚至有點害怕看不見的未知變數。")
  print("這時你擔心、害怕，雖然和男主已經在一起很久了，但還是時不時懷疑他外面有女人，或是不再愛自己了")
  print("因為猜忌、懷疑，導致你們不斷爭吵，最後決定不再拖累彼此。")
# Out:
# 歡迎來到這個遊戲
# 請輸入你的姓名: yu
# 我是yu,今年26歲，是個朝九晚五的上班族，總是被媽媽催婚
# 你素顏去買早餐 看到一個超帥的帥哥在吃早餐
# Q1 這時，你要不要去跟他要聯絡方式
# 請輸入你的回答 ({1}要/{2}不要) : 1
# 拿到他的聯絡方式，順便給媽媽一個交代 (好感度+5)
# Q2.男生:你家住哪裡?
# 請輸入你的回答 ({1}沉默/{2}直接說) : 2
# 男主:我也是ㄟ!真巧(好感度+5)
# 你們就一起走 走到家才發現兩個人竟然住在對面!
# 你們兩個相視而笑。
# 聊天過程很愉快，這時你決定明天要不要約男主吃早餐?
# [1]要 [2]不要1
# 當然要！(男主有點意外，但也暗自竊喜，這個女生好可愛) (好感度+5)
# 明天和他一起吃飯的你要？
# [1]精心打扮 [2]素顏赴約1
# 絕對要畫好畫滿！男主非常驚訝女主的改變，完全就是自己的理想型 (好感度+10)
# 你一整個晚上都很期待明天的早餐之約。
# 隔天，你和男主相約在家門口一起去吃早餐。
# 一路上你們兩個都很害羞，不知道要怎麼開口打破沉默。
# 你決定等一下在吃早餐的時候一定要主動開話題。
# 吃早餐時會選擇甚麼話題當開頭呢？
# [1]喜歡和討厭的食物 [2]ㄟ~你喜歡什麼類型的女生阿？[3] 你今年幾歲、薪資多少巴拉巴拉的身家調查 : 1
# 你的選擇是... 1
# 男生:我喜歡苦瓜、西瓜、哈密瓜
# 你:我不喜歡苦瓜、西瓜、哈密瓜，但喜歡你 (好感度+20)
# 你們在吃早餐時相談甚歡，到了要各自去上班的時候，你會說什麼呢？
# [1]謝謝你今天陪我吃早餐，你什麼時後有空呢? [2]先走了喔，拜 : 1
# 你的選擇是... 1
# 我周末都有空呀，到時候再一起吃早餐吧！(好感度+5)
# 已經持續一個月跟男主在周末吃早餐了，有時吃飽後也會一起去看電影、遊樂園等等，越來越喜歡男主角。而今天是週末又到了相約吃早餐的日子。
# 見到男主角後你會？
# 請輸入你的回答 ({1}我有點....(很害羞的臉)/{2}安於現狀，等待男主主動出擊) : 你的選擇是...1
# 男主說:等一下!這種事應該我來說，我喜歡你。(好感度+30)
# 請累積你所得到的好感度並輸入 : 1
# ...

# %% [markdown]
# A109010040 新聞一甲 掌聿
# A109010154 新聞一甲 王予軒
# A109010166
